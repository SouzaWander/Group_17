# %%
from energy_analysis import EnergyAnalysis
import pandas as pd

# %%
object = EnergyAnalysis("https://nyc3.digitaloceanspaces.com/owid-public/data/energy/owid-energy-data.csv", "energy_data.csv")

# %%
object.download_file()
# Out:
# ('./downloads/energy_data.csv', <http.client.HTTPMessage object at 0x7fe6dffcfd60>)

# %%
object.show_consumption("Portugal",1)
# Out:
# /home/wandersouza/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /home/wandersouza/Desktop/Nova/adPro/Group_17/energy_analysis.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["year"] = aux["year"]

# %%
"Portugal" in object.df.country.unique()
# Out:
# True
