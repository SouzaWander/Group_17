# %% [markdown]
# # Project Ergo: Energy Analysis
# **Group:** 17
#
# **Member:**
# - Wander Pereira Souza
# - José Maria Costa Correia Botelho de Sousa
# - Yannick Schad

# %%
import sys
sys.path.append('functions/')
from energy_analysis import EnergyAnalysis

# Crete a instance of EnergyAnalysis
object = EnergyAnalysis()

# Ingnore the warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# File already exists!

# %% [markdown]
# ## Day 1

# %% [markdown]
# #### Total Energy Consumption, GDP and the Population of each Country
# ##### The first step in the analysis was to compare energy consumption with the GDP of individual countries over a more extended period. The X-axis shows GDP per country and the Y-axis total energy consumption. The first graph shows the year 1990, the second the year 2016.

# %%
object.gapminder(1990)
object.gapminder(2016)

# %% [markdown]
# **Findings:**
# - Both graphs show a positive correlation between GDP and energy consumption. The higher a country's GDP, the higher its energy consumption.
# - It is also noticeable that the energy demand and GDP of the largest countries in the world have increased more than that of other countries. In 2016, the four largest countries in the world also had the highest energy demand. (This can be explained by the fact that India and China have made economic progress in the last 25 years).
# - The comparison of the two graphs also shows the population growth from 1990 to 2016. On the second graph, the dots are more significant. In 1990 the world population was 5.3 billion. In 2016, 7.6 billion.

# %% [markdown]
# ### Country Analysis

# %% [markdown]
# Three countries were selected for further analysis (Germany, Russia, China). All countries are members of the G20. Germany is a member of the EU. And EU has a carbon tax, which means carbon emissions have a cost.

# %% [markdown]
# #### Total Consumption of Germany, Russia and China
# ##### Plots of the total consumptions of the past years

# %%
object.show_consumption("Germany", False)
object.show_consumption("Russia", False)
object.show_consumption("China", False)

# %% [markdown]
# **Findings:**
# - **Germany**
#     - In Germany, absolute consumption has increased by about 15% over the last 50 years.
#     - As seen in the plot, coal consumption was one of the largest in 1970. Since then, however, it has steadily decreased.
#     - In addition, it can be seen that gas consumption has increased steadily. The consumption of nuclear energy has decreased in recent years. In 2011, the German government decided to phase out nuclear power.
#     - Finally, you can also see how sustainable energy sources such as wind or solar have increased since 2005.
#
#
# - **Russia**
#     - The graph of Russia shows that there is no data in the database before 1985.
#     - The most significant consumption reaches Russia at the end of the 80s. After that, consumption falls until the mid-1990s, before rising again until today. This could have something to do with the collapse of the Soviet Union.
#     - It should also be mentioned that sustainable energy does not play a role in Russia.
#     - The primary energy source is gas, which Russia itself produces in the country.
#
#
# - **China**
#     - In China, there has been an enormous increase in energy consumption. While the increase from 1970 to 2000 was moderate, it has risen sharply in the last 20 years.
#     - Coal has always accounted for the largest share, followed by oil consumption.
#     - Since 2010, the consumption of renewable energy can also be seen.

# %% [markdown]
# #### Relative Consumption of Germany, Russia and China
# ##### Plots of  normalized consumptions of the past years

# %%
object.show_consumption("Germany", True)
object.show_consumption("Russia", True)
object.show_consumption("China", True)

# %% [markdown]
# **Findings:**
# - **Germany**
#     - In Germany, the nuclear share is declining due to the nuclear phase-out.
#     - The graph also shows that the share of renewable energy has risen sharply. In the last 20 years, it has increased from almost 0 to 10 per cent today.
#     - Germany's nuclear phase-out can, but cannot, be compensated with renewable energy sources alone. The share of gas and oil has increased. This mostly comes from abroad. With Nord Stream I gas pipeline, Germany has an energy source from Russia. But the energy budget is dependent on it. This partly explains Germany's reluctance to take action against the Russian invasion of Ukraine.
#
#
# - **Russia**
#     - The graph of Russia shows no significant change in the shares over the last 50 years.
#     - Only the consumption of coal decreases, which is compensated by a higher consumption of gas. This can be produced relatively cheaply in the own country.
#     - As mentioned before, renewable energy sources have not played a role in Russia in the last 50 years.
#
#
# - **China**
#     - The graph of China shows that the largest share by far is Coal. Although the percentage has decreased, it still accounts for a large proportion.
#     - As in Germany, the share of renewable energies has increased in China since 2010, albeit at a more modest level. Today, it is still below 5 per cent.

# %% [markdown]
# #### GDP Evolution of Germany, Russia, China
# ##### Plot the gdp of the selected countries over time

# %%
object.gdp_country(["Germany", "Russia", "China"])

# %% [markdown]
# **Findings:**
# - The graph shows the gigantic development of China's GDP in the last 30 years. While China was still the weakest country in 1970, it caught up with the other two countries by 1990. Today the difference is striking and shows the economic strength of China over Russia and Germany.
#
#
# - The blue line of Germany shows a small but steady growth over the last 50 years. Further to stand is that after the fall of the Berlin Wall in 1989, the curve rose slightly stronger.
#
#
# - Russia's curve is the most volatile. Russia experienced a sharp decline after 1990 (disintegration of the Soviet Union). It only recovers after the turn of the millennium. Since 2010, GDP has been falling slightly again.
#
# - In Russia and Germany, the effects of the 2010 financial crisis on GDP can be seen very clearly. Both countries have a kink in their development. This is stronger in Russia, however. In China, the effects are less noticeable.
#
# - The impact of the Covid pandemic on GDP cannot be seen because data from those years are not yet available.

# %% [markdown]
# #### Total Consumption Evolution of Germany, Russia, China
# ##### Plot the total consumption of the selected countries over time

# %%
object.consumption_country(["Germany", "Russia", "China"])

# %% [markdown]
# **Findings:**
# - The graph shows an extreme increase in China since 2000. The consumption of China has tripled in the last 20 years.
#
#
# - As for the reasons already mentioned above, the consumption of Russia decreased at the beginning of the 1990s. Since 2000, consumption has been steadily increasing slightly.
#
#
# - You can see that the blue line of Germany hardly changes in this graph. One can prove this with the third graph in this notebook about the energy consumption of Germany. There, too, you can see no significant change.It is also noteworthy that Germany has significantly lower consumption than Russia most of the time.

# %% [markdown]
# ### Overall Analysis after Day 1

# %% [markdown]
# If we compare energy consumption with GDP, we see a clear positive correlation. The higher the GDP of Germany, Russia or China, the higher the consumption. Furthermore, political or economic events could be clearly seen in GDP and energy consumption graphs.The analyses have also shown that large countries in particular also have a significant energy demand. And this has increased more than in smaller countries in the last 30 years.

# %% [markdown]
# ## Day 2
#
# On the second day, we took a closer look at the emission and consumption of these countries, looked at their correlation and venture a forecast for the next five years.
#
# ### Correlation between Emission and Consumption

# %% [markdown]
# We plot the Total Consumption and Emission of Germany, Russia and China over the last 50 Years. In doing so, we created a twin Axes sharing the x-axis. On the left side, you see the total consumption of the country. On the right side are the total emissions of a nation.

# %%
object.consumption_emission_country(["Germany", "Russia", "China"])

# %% [markdown]
# **Findings:**
# - It is noticeable that there is a clear positive correlation between consumption and emissions. The higher the one, the higher the other.
#
#
# - As in the previous charts, this also reflects China's economic and social development. In the last 20 years, China has had significantly higher consumption and emission.

# %% [markdown]
# ### Deep Dive into Emission and Consumption and forcast
#
# We took a closer look at the emissions and consumption of these three countries. And with the help of the ARIMA family algorithm, we make and plot predictions about a given country's total emission and consumption values.

# %% [markdown]
# ### Germany

# %%
object.forecast(5,"DEU")

# %% [markdown]
# **Findings:**
# - It can be seen that total consumption and emissions were highest in Germany in the early 1980s.
#
# - Since then, emissions have fallen in a reasonably straight line. Consumption, with some fluctuations, is much lower than in 1980.
#
# - In 2021, Germany introduced a carbon tax. Therefore, it can be assumed that consumption and emissions will continue to decrease in the future.

# %% [markdown]
# ### Russia

# %%
object.forecast(5,"RUS")

# %% [markdown]
# **Findings:**
# - The graphs of Russia show a steady slight increase in consumption and emission since the late 1990s.
#
# - There is no carbon tax in Russia, and sustainable energy sources are not promoted.
#
# - The forecast follows the trend and shows a slight increase in the next few years.

# %% [markdown]
# ### China

# %%
object.forecast(5,"CHN")

# %% [markdown]
# **Findings:**
# - Like the previous graphs, Chinese consumption and emissions show a sharp increase.
#
# - It can be seen that emissions stagnate slightly after 2010, but are followed by a rise shortly afterwards.
#
# - The trend for Chinese consumption and emission continues to point upwards in the coming years.

# %%
object.Emissions_Consumption(1990)
object.Emissions_Consumption(2016)

# %% [markdown]
# ## Learnings
#
# The first day showed a clear correlation between GDP and energy consumption. Especially large nations have an enormous share in global energy consumption.
#
# On the second day, we analyzed three countries and found that their developments were very different. There is a correlation between energy consumption and emissions everywhere, but while it decreases, e.g. in Germany, it increases strongly in China.
#
# Two things can help decarbonization: First, a carbon tax like many European countries have. Second is the promotion of renewable energy sources, as is the case in Germany. So it is possible that already today, in Germany, 10 per cent of the energy consumption comes from renewable energy.
